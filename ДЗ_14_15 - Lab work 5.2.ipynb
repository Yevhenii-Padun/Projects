# %% [markdown]
# ___
#
# <a href='https://mainacademy.ua/'> <img src='https://mainacademy.ua/wp-content/uploads/2019/03/logo-main.png' alt = 'Хмм, щось з інтернетом'/></a>
# ___
#
# # Module 5: Data analysis with NumPy and Pandas

# %% [markdown]
# ## Lab work 5.2

# %% [markdown]
# #### Мета:
#
# * навчитися працювати із бібліотекою Pandas в Python.

# %% [markdown]
# ### Завдання:

# %%
import pandas as pd

# %% [markdown]
# Вивести версію та конфігурацію бібліотеки:

# %%
print (pd.__version__)
# Out:
# 1.4.2

# %%
#я не знайшов як вивести конфігурацію

# %%
df = pd.read_csv('Ecommerce Purchases.txt')

# %%
df
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# Скільки рядків і стовпців в наборі даних:

# %%
df.shape
# Out:
# (10000, 14)

# %% [markdown]
# Перевірити, чи в наборі даних містяться порожні значення:

# %%
df.to_numpy()[~df.isnull()]   #виходячи із даного у таблиці відсутні порожні значення
# Out:
# array(['16629 Pace Camp Apt. 448\nAlexisborough, NE 77130-7478', '46 in',
#        'PM', ..., '176.119.198.199', 'el', 67.59], dtype=object)

# %%
df.isnull()
# Out:
#       Address    Lot  AM or PM  Browser Info  Company  Credit Card  \
# 0       False  False     False         False    False        False
# 1       False  False     False         False    False        False
# 2       False  False     False         False    False        False
# 3       False  False     False         False    False        False
# 4       False  False     False         False    False        False
# ...       ...    ...       ...           ...      ...          ...
# 9995    False  False     False         False    False        False
# 9996    False  False     False         False    False        False
# 9997    False  False     False         False    False        False
# 9998    False  False     False         False    False        False
# 9999    False  False     False         False    False        False
#
#       CC Exp Date  CC Security Code  CC Provider  Email    Job  IP Address  \
# 0           False             False        False  False  False       False
# ...

# %% [markdown]
# Яка середня ціна закупки (Purchase Price):

# %%
df1=df[['Purchase Price']]
df1.mean()
# Out:
# Purchase Price    50.347302
# dtype: float64

# %%
df.describe()   #можна перевірити вивівши основні показники числових стовпців таблиці
# Out:
#         Credit Card  CC Security Code  Purchase Price
# count  1.000000e+04      10000.000000    10000.000000
# mean   2.341374e+15        907.217800       50.347302
# std    2.256103e+15       1589.693035       29.015836
# min    6.040186e+10          0.000000        0.000000
# 25%    3.056322e+13        280.000000       25.150000
# 50%    8.699942e+14        548.000000       50.505000
# 75%    4.492298e+15        816.000000       75.770000
# max    6.012000e+15       9993.000000       99.990000

# %% [markdown]
# Скільки людей користуються англійською мовою "en" на веб-сайті:

# %%
df[df['Language'] == 'en']   #По кількості рядків бачимо, що 1098 людей користуються англійською мовою "en"
# Out:
#                                                 Address    Lot AM or PM  \
# 11               349 Laurie Parks\nThomasview, ID 08970  30 kK       PM
# 12      733 Heather Rest Apt. 670\nBoltonport, UT 78662  69 DO       AM
# 22     625 Laura Summit Suite 112\nShortmouth, AK 97156  45 oa       PM
# 26          5334 Sheppard Fort\nNorth Kirsten, ND 71170  40 ND       AM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# ...                                                 ...    ...      ...
# 9961        714 Joshua Ridges\nCarpenterville, NJ 37418  84 rK       PM
# 9963  3865 Davis Meadow Suite 915\nPort Stacieview, ...  11 fo       AM
# 9970              0060 Keith Stream\nWestport, CO 47097  11 nt       PM
# 9973     92126 Daniel Streets\nNorth Patricia, IA 10477  04 QN       PM
# 9979  00490 Joseph Haven Apt. 149\nWest Keithfurt, S...  69 XK       PM
#
#                                            Browser Info  \
# ...

# %%
len(df[df['Language'] == 'en'])   #можна і через виведення кількості загальної по даним умовам
# Out:
# 1098

# %% [markdown]
# Скільки людей має посаду «Lawyer»?

# %%
len(df[df['Job'] == 'Lawyer'])
# Out:
# 30

# %% [markdown]
# Скільки людей зробило покупку вранці та скільки людей зробило покупку після обіду?

# %%
len(df[df['AM or PM'] == 'AM'])
# Out:
# 4932

# %%
len(df[df['AM or PM'] == 'PM'])
# Out:
# 5068

# %% [markdown]
# Які 5 найпоширеніших назв вакансій?

# %%
df2=df.groupby('Job').count()  #групую по професіям
df2
# Out:
#                                   Address  Lot  AM or PM  Browser Info  \
# Job
# Academic librarian                     11   11        11            11
# Accommodation manager                  17   17        17            17
# Accountant, chartered                  20   20        20            20
# Accountant, chartered certified        18   18        18            18
# Accountant, chartered management       15   15        15            15
# ...                                   ...  ...       ...           ...
# Water quality scientist                18   18        18            18
# Web designer                           20   20        20            20
# Wellsite geologist                     24   24        24            24
# Writer                                 10   10        10            10
# Youth worker                           18   18        18            18
#
#                                   Company  Credit Card  CC Exp Date  \
# Job
# ...

# %%
df['Job'].unique()  #вивів всі назви професій (вакансій я не бачу)
# Out:
# array(['Scientist, product/process development', 'Drilling engineer',
#        'Customer service manager', 'Fine artist', 'Fish farm manager',
#        'Dancer', 'Event organiser', 'Financial manager',
#        'Forensic scientist', 'Development worker, community',
#        'Diagnostic radiographer', 'Surveyor, quantity',
#        'Accountant, chartered public finance', 'Acupuncturist',
#        'Retail manager', 'Therapist, art', 'Designer, jewellery',
#        'Photographer', 'Designer, interior/spatial',
#        'Public relations officer', 'Presenter, broadcasting',
#        'Field seismologist', 'Musician',
#        'Training and development officer', "Barrister's clerk",
#        'Careers adviser', 'Scientist, research (life sciences)',
#        'Recycling officer', 'Fisheries officer', 'Sales executive',
#        'Civil Service fast streamer', 'Theatre stage manager',
#        'Therapist, music', 'Lecturer, further education',
# ...

# %%
df['Job'].value_counts()   #перші 5 є найпоширенішими
# Out:
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
#                                  ..
# Prison officer                    7
# Editor, film/video                6
# Actuary                           6
# Information systems manager       5
# Investment analyst                5
# Name: Job, Length: 623, dtype: int64

# %%
df3=df['Job'].value_counts()
df3[:5]
# Out:
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
# Name: Job, dtype: int64

# %% [markdown]
# Хто здійснив покупку, яка надійшла від Lot: "90 Wt", та якою була ціна придбання для цієї транзакції?

# %%
df[(df['Lot'] == '90 Wt') ]   #запитуванна інформація в таблиці відсутня
# Out:
# Empty DataFrame
# Columns: [Address, Lot, AM or PM, Browser Info, Company, Credit Card, CC Exp Date, CC Security Code, CC Provider, Email, Job, IP Address, Language, Purchase Price]
# Index: []

# %% [markdown]
# Яка електронна адреса особи з таким номером кредитної картки: 4926535242672853 ?

# %%
df3=df[df['Credit Card'] == 4926535242672853] 
df3
# Out:
#                                                 Address    Lot AM or PM  \
# 1234  2470 Maria Manors Suite 185\nJoneshaven, MN 87251  82 UX       PM
#
#                                            Browser Info  \
# 1234  Mozilla/5.0 (X11; Linux x86_64; rv:1.9.5.20) G...
#
#                     Company       Credit Card CC Exp Date  CC Security Code  \
# 1234  Cole, King and Bowers  4926535242672853       09/21               188
#
#            CC Provider                         Email  \
# 1234  American Express  bondellen@williams-garza.com
#
#                                     Job    IP Address Language  Purchase Price
# 1234  Planning and development surveyor  159.182.3.50       ru           77.88

# %%
df3['Email']  #виводжу емеіл особи із номер необхідної кредитиної картки
# Out:
# 1234    bondellen@williams-garza.com
# Name: Email, dtype: object

# %% [markdown]
# Скільки людей використовує American Express  і здійснили покупку на суму понад 100 доларів?

# %%
df[(df['CC Provider'] == 'American Express') & (df['Purchase Price'] > 100)]   #запитуванна інформація в таблиці відсутня
# Out:
# Empty DataFrame
# Columns: [Address, Lot, AM or PM, Browser Info, Company, Credit Card, CC Exp Date, CC Security Code, CC Provider, Email, Job, IP Address, Language, Purchase Price]
# Index: []

# %% [markdown]
# Скільки людей мають кредитну картку, термін дії якої закінчується в 2025 році?

# %%
df[(df['CC Exp Date'] >= 1/25) & (df['CC Exp Date'] <= 12/25)]  #щось я не вірно в умові вказав
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [224], in <cell line: 1>()
# ----> 1 df[(df['CC Exp Date'] >= 1/25) & (df['CC Exp Date'] <= 12/25)]
#
# File C:\anaconda3\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File C:\anaconda3\lib\site-packages\pandas\core\arraylike.py:60, in OpsMixin.__ge__(self, other)
#      58 @unpack_zerodim_and_defer("__ge__")
#      59 def __ge__(self, other):
# ---> 60     return self._cmp_method(other, operator.ge)
#
# File C:\anaconda3\lib\site-packages\pandas\core\series.py:5623, in Series._cmp_method(self, other, op)
#    5620 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    5622 with np.errstate(all="ignore"):
# ...

# %% [markdown]
# Які найкращі 5 найпопулярніших постачальників / хостів електронної пошти (наприклад, gmail.com, yahoo.com тощо ...).

# %%
df.groupby('Email').count()
# Out:
#                             Address  Lot  AM or PM  Browser Info  Company  \
# Email
# aabbott@hotmail.com               1    1         1             1        1
# aacosta@maddox-mann.info          1    1         1             1        1
# aallen@yahoo.com                  1    1         1             1        1
# aalvarez@yahoo.com                1    1         1             1        1
# aandersen@gmail.com               1    1         1             1        1
# ...                             ...  ...       ...           ...      ...
# zwhite@nichols-willis.com         1    1         1             1        1
# zwilson@yahoo.com                 1    1         1             1        1
# zwright@suarez.biz                1    1         1             1        1
# zyork@fischer-harrison.com        1    1         1             1        1
# zyoung@yahoo.com                  1    1         1             1        1
#
# ...

# %%
df['Email'].value_counts()  

#df['Email'].find('@')
#Я не розумію, як з назви електронної пошти можна виокремити gmail.com, yahoo.com тощо. Підскажіть будб-ласка
# Out:
# leekathy@yahoo.com           2
# joshua41@hotmail.com         2
# christopher29@gmail.com      2
# ethomas@hotmail.com          2
# brownjohn@hotmail.com        2
#                             ..
# jamesbarnett@gomez.org       1
# hernandezrobert@frank.com    1
# lindseywilliams@pratt.com    1
# ann28@hotmail.com            1
# rachelford@vaughn.com        1
# Name: Email, Length: 9954, dtype: int64

# %% [markdown]
# Виведіть зведену таблицю по браузерах(Browser Info), посаді(Job), та кількості транзакцій :

# %%
df5=df[['Browser Info', 'Job', 'Lot']]  #Lot - це кількість транзакцій, якщо я правильно зрозумів
df5
# Out:
#                                            Browser Info  \
# 0     Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1     Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2     Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4     Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
# ...                                                 ...
# 9995  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/5352 ...
# 9996  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 9997  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_7...
# 9998  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_8;...
# 9999  Mozilla/5.0 (X11; Linux i686; rv:1.9.5.20) Gec...
#
#                                          Job    Lot
# 0     Scientist, product/process development  46 in
# 1                          Drilling engineer  28 rn
# 2                   Customer service manager  94 vE
# 3                          Drilling engineer  36 vm
# ...

# %% [markdown]
# Створіть нову колонку "Actual price", яка утворюється із "Purchase Price" та націнки за принципом:
# - якщо "Purchase Price" > 50, націнка 20%
# - якщо "Purchase Price" > 100, націнка 10%
# - в інших випадках націнка 30%

# %%
actual_price = []
for el in df['Purchase Price'].tolist():
    if el >50:
        actual_price.append (el*1.2)
    elif el >100:
        actual_price.append (el*1.1)
    else:
        actual_price.append (el*1.3)
df['Actual price'] = actual_price
df
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# Зробіть рангування набору даних по "Language" та "Actual price" в порядку спадання ціни.
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rank.html

# %%
df_1_1 = df['Language'].rank(method = 'max', na_option = 'keep', ascending=False)
df_1_1
# Out:
# 0        8845.0
# 1        5515.0
# 2       10000.0
# 3        6610.0
# 4        6610.0
#          ...
# 9995     4418.0
# 9996     3332.0
# 9997     8845.0
# 9998     6610.0
# 9999     8845.0
# Name: Language, Length: 10000, dtype: float64

# %%
df_1_2 = df['Actual price'].rank(method = 'max', na_option = 'keep', ascending=False, pct=False)
df_1_2
# Out:
# 0        192.0
# 1       2989.0
# 2       9895.0
# 3       2257.0
# 4       2280.0
#          ...
# 9995    1853.0
# 9996    7451.0
# 9997    1659.0
# 9998    6127.0
# 9999    3294.0
# Name: Actual price, Length: 10000, dtype: float64

# %% [markdown]
# Колонку "Language" (категоріальна змінна) "закодуйте", тобто утворити індикаторні колоник. В наборі не повинна залишитися колонка "Language".
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rank.html

# %%
#Я не знаю як закодувати , утворити індикаторні колонки
df_1_3=df.drop(['Language'], axis = 1)  #видаляю колонку (Language)
df_1_3
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# Кінцевий набір даних збережіть у файл з розширенням csv.

# %%
df.to_csv('Ecommerce_Purchases_new.csv')
